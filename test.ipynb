# %%
import numpy as np
from math import *
import argparse
import matplotlib.pyplot as plt
import copy
import argparse

from trackingerror import Detector, inputfromfile, plot_fixedp, plot_fixedeta
# Out:
# /Users/sgfx/Desktop/CERN/Project/ATLAS_ITk_TrackingResolution/TrackingResolution-3.0-modified/trackingerror.py:773: SyntaxWarning: invalid escape sequence '\m'
#   ylabel = ylabel + ' [$\mu m$]'
# /Users/sgfx/Desktop/CERN/Project/ATLAS_ITk_TrackingResolution/TrackingResolution-3.0-modified/trackingerror.py:812: SyntaxWarning: invalid escape sequence '\m'
#   ylabel = ylabel + ' [$\mu m$]'
# /Users/sgfx/Desktop/CERN/Project/ATLAS_ITk_TrackingResolution/TrackingResolution-3.0-modified/trackingerror.py:816: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('$\eta$')

# %%
plot_fixedeta('ATLAS.txt','sigma(d)')
# Out:
# #	Width	Resolutionxy	Resolutionz	position
# 1  	0.0174	1.43e-05		1.43e-05		0.039
# 2  	0.0174	1.43e-05		1.43e-05		0.099
# 3  	0.0174	1.43e-05		1.43e-05		0.16
# 4  	0.0174	1.43e-05		1.43e-05		0.228
# 5  	0.0174	1.43e-05		1.43e-05		0.291
# 6  	0.0505	2.19e-05		2.19e-05		0.399
# 7  	0.0505	2.19e-05		2.19e-05		0.562
# 8  	0.0505	2.19e-05		2.19e-05		0.762
# 9  	0.0505	2.19e-05		2.19e-05		1
# Successfully read 9 layers
# Resolution in the first pt bin 81.1142240927586

# %%
plot_fixedp('ATLAS.txt','sigma(d)')
# Out:
# #	Width	Resolutionxy	Resolutionz	position
# 1  	0.0174	1.43e-05		1.43e-05		0.039
# 2  	0.0174	1.43e-05		1.43e-05		0.099
# 3  	0.0174	1.43e-05		1.43e-05		0.16
# 4  	0.0174	1.43e-05		1.43e-05		0.228
# 5  	0.0174	1.43e-05		1.43e-05		0.291
# 6  	0.0505	2.19e-05		2.19e-05		0.399
# 7  	0.0505	2.19e-05		2.19e-05		0.562
# 8  	0.0505	2.19e-05		2.19e-05		0.762
# 9  	0.0505	2.19e-05		2.19e-05		1
# Successfully read 9 layers
# Resolution in the first eta bin 65.99283286102256

# %%
plot_fixedp('ATLAS.txt','sigma(z)')
# Out:
# #	Width	Resolutionxy	Resolutionz	position
# 1  	0.0174	1.43e-05		1.43e-05		0.039
# 2  	0.0174	1.43e-05		1.43e-05		0.099
# 3  	0.0174	1.43e-05		1.43e-05		0.16
# 4  	0.0174	1.43e-05		1.43e-05		0.228
# 5  	0.0174	1.43e-05		1.43e-05		0.291
# 6  	0.0505	2.19e-05		2.19e-05		0.399
# 7  	0.0505	2.19e-05		2.19e-05		0.562
# 8  	0.0505	2.19e-05		2.19e-05		0.762
# 9  	0.0505	2.19e-05		2.19e-05		1
# Successfully read 9 layers
# Resolution in the first eta bin 64.40468549922197
