# %%
from trackingerror import *
from ITk import ITk_adjust_r0
# Out:
# /Users/sgfx/Desktop/CERN/Project/TrackingResolution-ITk/trackingerror.py:835: SyntaxWarning: invalid escape sequence '\m'
#   ylabel = ylabel + ' [$\mu m$]'
# /Users/sgfx/Desktop/CERN/Project/TrackingResolution-ITk/trackingerror.py:882: SyntaxWarning: invalid escape sequence '\m'
#   ylabel = ylabel + ' [$\mu m$]'
# /Users/sgfx/Desktop/CERN/Project/TrackingResolution-ITk/trackingerror.py:886: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('$\eta$')

# %%
r0_values = np.linspace(0.025, 0.040, 5)  # Different values of r0 to test; can be rewritten with arange if needed
for r0 in r0_values:
    itk = ITk_adjust_r0(r0)
    print(itk)
    plot_fixedp(itk, 'sigma(d)', B=2, p=2, input_mode='detector', label='r0={:.5f} mm'.format(r0), eta_max=2.0)
    plt.title("ITk with varying r0 values")
# Out:
# Detector: 9 layers
# Idx	Position[m]	d[X0]	res_xy	res_z	ms
# 1	0.025	0.0174	7.21688e-06	2.88675e-05	0
# 2	0.099	0.0174	1.44338e-05	1.44338e-05	0
# 3	0.16	0.0174	1.44338e-05	1.44338e-05	0
# 4	0.228	0.0174	1.44338e-05	1.44338e-05	0
# 5	0.291	0.0174	1.44338e-05	1.44338e-05	0
# 6	0.399	0.0505	2.3094e-05	2.3094e-05	0
# 7	0.562	0.0505	2.3094e-05	2.3094e-05	0
# 8	0.762	0.0505	2.3094e-05	2.3094e-05	0
# 9	1	0.0505	2.3094e-05	2.3094e-05	0
# Resolution in the first eta bin 22.122636267619022
# Detector: 9 layers
# Idx	Position[m]	d[X0]	res_xy	res_z	ms
# 1	0.02875	0.0174	7.21688e-06	2.88675e-05	0
# 2	0.099	0.0174	1.44338e-05	1.44338e-05	0
# 3	0.16	0.0174	1.44338e-05	1.44338e-05	0
# 4	0.228	0.0174	1.44338e-05	1.44338e-05	0
# 5	0.291	0.0174	1.44338e-05	1.44338e-05	0
# 6	0.399	0.0505	2.3094e-05	2.3094e-05	0
# 7	0.562	0.0505	2.3094e-05	2.3094e-05	0
# 8	0.762	0.0505	2.3094e-05	2.3094e-05	0
# 9	1	0.0505	2.3094e-05	2.3094e-05	0
# Resolution in the first eta bin 25.09354639258724
# Detector: 9 layers
# ...
