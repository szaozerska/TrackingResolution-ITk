# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt

from trackingerror import plot_fixedp, plot_fixedeta
from ITk import ITk
from ATLAS import ATLAS_PhaseII
# Out:
# /Users/sgfx/Desktop/CERN/Project/TrackingResolution-ITk/trackingerror.py:813: SyntaxWarning: invalid escape sequence '\m'
#   ylabel = ylabel + ' [$\mu m$]'
# /Users/sgfx/Desktop/CERN/Project/TrackingResolution-ITk/trackingerror.py:860: SyntaxWarning: invalid escape sequence '\m'
#   ylabel = ylabel + ' [$\mu m$]'
# /Users/sgfx/Desktop/CERN/Project/TrackingResolution-ITk/trackingerror.py:864: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('$\eta$')

# %%
itk = ITk()
atlas = ATLAS_PhaseII()

plot_fixedp(atlas, 'sigma(d)', input_mode='detector', label='ATLAS Phase II, p=1 GeV, mass=0.106')
plot_fixedp(itk, 'sigma(d)', input_mode='detector', label='ITk, p=1 GeV, mass=0.106')
# Out:
# Resolution in the first eta bin 69.64645987393048
# Resolution in the first eta bin 54.80118918701573

# %%
plot_fixedp(atlas, 'sigma(z)', input_mode='detector', label='ATLAS Phase II, p=1 GeV, mass=0.106')
plot_fixedp(itk, 'sigma(z)', input_mode='detector', label='ITk, p=1 GeV, mass=0.106')
# Out:
# Resolution in the first eta bin 82.2435395709568
# Resolution in the first eta bin 67.03593470041787
