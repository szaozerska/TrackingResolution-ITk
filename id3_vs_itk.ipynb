# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt

from trackingerror import plot_fixedp
from ITk import ITk
from ATLAS import ATLAS_PhaseII

# %%
itk = ITk()
atlas = ATLAS_PhaseII()

plot_fixedp(atlas, 'sigma(d)', B=2, p=2, input_mode='detector', label='ATLAS Phase II, p=2 GeV, mass=0.106')
plot_fixedp(itk, 'sigma(d)', B=2, p=2, input_mode='detector', label='ITk, p=2 GeV, mass=0.106')
# Out:
# Resolution in the first eta bin 43.41519263839257
# Resolution in the first eta bin 29.3574185900494
# Detector: 9 layers
# Idx	Position[m]	d[X0]	res_xy	res_z	ms
# 1	0.034	0.0174	7.21688e-06	2.88675e-05	0
# 2	0.099	0.0174	1.44338e-05	1.44338e-05	0
# 3	0.16	0.0174	1.44338e-05	1.44338e-05	0
# 4	0.228	0.0174	1.44338e-05	1.44338e-05	0
# 5	0.291	0.0174	1.44338e-05	1.44338e-05	0
# 6	0.399	0.0505	2.3094e-05	2.3094e-05	0
# 7	0.562	0.0505	2.3094e-05	2.3094e-05	0
# 8	0.762	0.0505	2.3094e-05	2.3094e-05	0
# 9	1	0.0505	2.3094e-05	2.3094e-05	0

# %%
plot_fixedp(atlas, 'sigma(z)', B=2, p=2, input_mode='detector', label='ATLAS Phase II, p=2 GeV, mass=0.106', eta_max=4.0)
plot_fixedp(itk, 'sigma(z)', B=2, p=2, input_mode='detector', label='ITk, p=2 GeV, mass=0.106', eta_max=4.0)
# Out:
# Resolution in the first eta bin 47.5435985400283
# Resolution in the first eta bin 46.252698423038325
# Detector: 9 layers
# Idx	Position[m]	d[X0]	res_xy	res_z	ms
# 1	0.034	0.0174	7.21688e-06	2.88675e-05	0
# 2	0.099	0.0174	1.44338e-05	1.44338e-05	0
# 3	0.16	0.0174	1.44338e-05	1.44338e-05	0
# 4	0.228	0.0174	1.44338e-05	1.44338e-05	0
# 5	0.291	0.0174	1.44338e-05	1.44338e-05	0
# 6	0.399	0.0505	2.3094e-05	2.3094e-05	0
# 7	0.562	0.0505	2.3094e-05	2.3094e-05	0
# 8	0.762	0.0505	2.3094e-05	2.3094e-05	0
# 9	1	0.0505	2.3094e-05	2.3094e-05	0

# %%
# RATIO COMPARISON: SIGMA(D)
# (could be turned into a function)

eta = np.linspace(0, 2.0, 100)
results_itk = []
results_id3 = []
var = 'sigma(d)'
for i in range(len(eta)):
    results_itk.append(itk.errorcalculation(p=2, B=2, eta=eta[i], m=0.106)[var])
    results_id3.append(atlas.errorcalculation(p=2, B=2, eta=eta[i], m=0.106)[var])
ratio = np.array(results_itk) / np.array(results_id3)
plt.plot(eta, ratio)
plt.xlabel('$\eta$')
plt.ylabel('{}: ITk / ATLAS Phase II'.format(var))
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\e'
# <>:13: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/06/4mfw39l90p15785y1mn_4fsh0000gn/T/ipykernel_1407/3799931575.py:13: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('$\eta$')
# Text(0, 0.5, 'sigma(d): ITk / ATLAS Phase II')

# %% [markdown]
# (Doesn't quite match the results in https://atlas.web.cern.ch/Atlas/GROUPS/PHYSICS/PAPERS/IDTR-2023-01/ so far, but it might be so because of the different detector layout params)

# %%
eta = np.linspace(0, 2.0, 100)
results_itk = []
results_id3 = []
var = 'sigma(z)'
for i in range(len(eta)):
    results_itk.append(itk.errorcalculation(p=2, B=2, eta=eta[i], m=0.106)[var])
    results_id3.append(atlas.errorcalculation(p=2, B=2, eta=eta[i], m=0.106)[var])
ratio = np.array(results_itk) / np.array(results_id3)
plt.plot(eta, ratio)
plt.xlabel('$\eta$')
plt.ylabel('{}: ITk / ATLAS Phase II'.format(var))
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\e'
# <>:10: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/06/4mfw39l90p15785y1mn_4fsh0000gn/T/ipykernel_1407/1351943582.py:10: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('$\eta$')
# Text(0, 0.5, 'sigma(z): ITk / ATLAS Phase II')

# %% [markdown]
# (shape is questionable, values too, but some resemblance is there)
